# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshvijayvargiaya/Practical-Deep-Learning-for-Coders-2.0/blob/master/Review_Classification_using_active_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# With the growth of data-centric Machine Learning, Active Learning has grown in popularity amongst businesses and researchers. Active Learning seeks to progressively train ML models so that the resultant model requires lesser amount of training data to achieve competitive scores.
#
# The structure of an Active Learning pipeline involves a classifier and an oracle. The oracle is an annotator that cleans, selects, labels the data, and feeds it to the model when required. The oracle is a trained individual or a group of individuals that ensure consistency in labeling of new data.
#
# The process starts with annotating a small subset of the full dataset and training an initial model. The best model checkpoint is saved and then tested on a balanced test set. The test set must be carefully sampled because the full training process will be dependent on it. Once we have the initial evaluation scores, the oracle is tasked with labeling more samples; the number of data points to be sampled is usually determined by the business requirements. After that, the newly sampled data is added to the training set, and the training procedure repeats. This cycle continues until either an acceptable score is reached or some other business metric is met.
#
# This tutorial provides a basic demonstration of how Active Learning works by demonstrating a ratio-based (least confidence) sampling strategy that results in lower overall false positive and negative rates when compared to a model trained on the entire dataset. This sampling falls under the domain of uncertanity sampling, in which new datasets are sampled based on the uncertanity that the model outputs for the corresponding label. In our example, we compare our model's false positive and false negative rates and annotate the new data based on their ratio.

# %% [markdown]
# # **Importing required libraries**

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import re
import string
tfds.disable_progress_bar()

# %% [markdown]
# # **Loading and preprocessing the data**
#
#
# > We will be using the IMDB reviews dataset for our experiments. This dataset has 50,000 reviews in total, including training and testing splits. We will merge these splits and sample our own, balanced training, validation and testing sets

# %%
dataset = tfds.load(
    "imdb_reviews",
    split="train + test",
    as_supervised=True,
    batch_size=-1,
    shuffle_files=False,
)
reviews, labels = tfds.as_numpy(dataset)

print("Total examples:", reviews.shape[0])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py:598: get_single_element (from tensorflow.python.data.experimental.ops.get_single_element) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.get_single_element()`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py:598: get_single_element (from tensorflow.python.data.experimental.ops.get_single_element) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.get_single_element()`.
# Total examples: 50000

# %% [markdown]
# Active learning starts with labeling a subset of data. For the ratio sampling technique that we will be using, we will need well-balanced training, validation and testing splits.

# %% [markdown]
# # Fitting the TextVectorization layer
#
#
# >Since we are working with text data, we will need to encode the text strings as vectors which would then be passed through an Embedding layer. To make this tokenization process faster, we use the map() function with its parallelization functionality.

# %%
val_split = 2500
test_split = 2500
train_split = 7500

# Separating the negative and positive samples for manual stratification
x_positives, y_positives = reviews[labels == 1], labels[labels == 1]
x_negatives, y_negatives = reviews[labels == 0], labels[labels == 0]

# Creating training, validation and testing splits
x_val, y_val = (
    tf.concat((x_positives[:val_split], x_negatives[:val_split]), 0),
    tf.concat((y_positives[:val_split], y_negatives[:val_split]), 0),
)
x_test, y_test = (
    tf.concat(
        (
            x_positives[val_split : val_split + test_split],
            x_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split : val_split + test_split],
            y_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
)
x_train, y_train = (
    tf.concat(
        (
            x_positives[val_split + test_split : val_split + test_split + train_split],
            x_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split + test_split : val_split + test_split + train_split],
            y_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
)

# Remaining pool of samples are stored separately. These are only labeled as and when required
x_pool_positives, y_pool_positives = (
    x_positives[val_split + test_split + train_split :],
    y_positives[val_split + test_split + train_split :],
)
x_pool_negatives, y_pool_negatives = (
    x_negatives[val_split + test_split + train_split :],
    y_negatives[val_split + test_split + train_split :],
)

# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

pool_negatives = tf.data.Dataset.from_tensor_slices(
    (x_pool_negatives, y_pool_negatives)
)
pool_positives = tf.data.Dataset.from_tensor_slices(
    (x_pool_positives, y_pool_positives)
)

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled negative pool: {len(pool_negatives)}")
print(f"Unlabeled positive pool: {len(pool_positives)}")
# Out:
# Initial training set size: 15000
# Validation set size: 5000
# Testing set size: 5000
# Unlabeled negative pool: 12500
# Unlabeled positive pool: 12500

# %%
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, "<br />", " ")
    return tf.strings.regex_replace(
        stripped_html, f"[{re.escape(string.punctuation)}]", ""
    )


vectorizer = layers.TextVectorization(
    3000, standardize=custom_standardization, output_sequence_length=150
)
# Adapting the dataset
vectorizer.adapt(
    train_dataset.map(lambda x, y: x, num_parallel_calls=tf.data.AUTOTUNE).batch(256)
)


def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label


train_dataset = train_dataset.map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
pool_negatives = pool_negatives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)
pool_positives = pool_positives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %% [markdown]
# # Creating Helper Functions

# %%
# Helper function for merging new history objects with older ones

def append_history(losses, val_losses, accuracy, val_accuracy, history):
  losses = losses + history.history["loss"]
  val_losses = val_losses + history.history["val_loss"]
  accuracy = accuracy + history.history["binary_accuracy"]
  val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
  return losses, val_losses, accuracy, val_accuracy

# Plotter Function

def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %% [markdown]
# # Creating the Model
#
#
# >We create a small bidirectional LSTM model. When using Active Learning, you should make sure that the model architecture is capable of overfitting to the initial data. Overfitting gives a strong hint that the model will have enough capacity for future, unseen data.

# %%
def create_model():
    model = keras.models.Sequential(
        [
            layers.Input(shape=(150,)),
            layers.Embedding(input_dim=3000, output_dim=128),
            layers.Bidirectional(layers.LSTM(32, return_sequences=True)),
            layers.GlobalMaxPool1D(),
            layers.Dense(20, activation="relu"),
            layers.Dropout(0.5),
            layers.Dense(1, activation="sigmoid"),
        ]
    )
    model.summary()
    return model

# %% [markdown]
# # Training on the entire dataset
# To show the effectiveness of Active Learning, we will first train the model on the entire dataset containing 40,000 labeled samples. This model will be used for comparison later.

# %%
def train_full_model(full_train_dataset, val_dataset, test_dataset):
    model = create_model()
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # We will save the best model at every epoch and load the best one for evaluation on the test set
    history = model.fit(
        full_train_dataset.batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[
            keras.callbacks.EarlyStopping(patience=4, verbose=1),
            keras.callbacks.ModelCheckpoint(
                "FullModelCheckpoint.h5", verbose=1, save_best_only=True
            ),
        ],
    )

    # Plot history
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["binary_accuracy"],
        history.history["val_binary_accuracy"],
    )

    # Loading the best checkpoint
    model = keras.models.load_model("FullModelCheckpoint.h5")

    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


# Sampling the full train dataset to train on
full_train_dataset = (
    train_dataset.concatenate(pool_positives)
    .concatenate(pool_negatives)
    .cache()
    .shuffle(20000)
)

# Training the full model
full_dataset_model = train_full_model(full_train_dataset, val_dataset, test_dataset)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 128)          384000
#
#  bidirectional (Bidirectiona  (None, 150, 64)          41216
#  l)
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 20)                1300
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 426,537
# Trainable params: 426,537
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 155/157 [============================>.] - ETA: 0s - loss: 0.5257 - binary_accuracy: 0.7541 - false_negatives: 3088.0000 - false_positives: 6668.0000
# Epoch 1: val_loss improved from inf to 0.39068, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 16s 52ms/step - loss: 0.5254 - binary_accuracy: 0.7544 - false_negatives: 3144.0000 - false_positives: 6682.0000 - val_loss: 0.3907 - val_binary_accuracy: 0.8438 - val_false_negatives: 509.0000 - val_false_positives: 272.0000
# Epoch 2/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3766 - binary_accuracy: 0.8468 - false_negatives: 2918.0000 - false_positives: 3210.0000
# Epoch 2: val_loss improved from 0.39068 to 0.34529, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 4s 27ms/step - loss: 0.3766 - binary_accuracy: 0.8468 - false_negatives: 2918.0000 - false_positives: 3210.0000 - val_loss: 0.3453 - val_binary_accuracy: 0.8574 - val_false_negatives: 425.0000 - val_false_positives: 288.0000
# Epoch 3/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.3362 - binary_accuracy: 0.8672 - false_negatives: 2550.0000 - false_positives: 2753.0000
# Epoch 3: val_loss did not improve from 0.34529
# 157/157 [==============================] - 4s 23ms/step - loss: 0.3361 - binary_accuracy: 0.8673 - false_negatives: 2551.0000 - false_positives: 2758.0000 - val_loss: 0.3714 - val_binary_accuracy: 0.8286 - val_false_negatives: 713.0000 - val_false_positives: 144.0000
# Epoch 4/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3125 - binary_accuracy: 0.8765 - false_negatives: 2375.0000 - false_positives: 2567.0000
# Epoch 4: val_loss did not improve from 0.34529
# 157/157 [==============================] - 4s 24ms/step - loss: 0.3125 - binary_accuracy: 0.8765 - false_negatives: 2375.0000 - false_positives: 2567.0000 - val_loss: 0.4846 - val_binary_accuracy: 0.8016 - val_false_negatives: 906.0000 - val_false_positives: 86.0000
# Epoch 5/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.2938 - binary_accuracy: 0.8856 - false_negatives: 2201.0000 - false_positives: 2368.0000
# Epoch 5: val_loss did not improve from 0.34529
# 157/157 [==============================] - 4s 24ms/step - loss: 0.2939 - binary_accuracy: 0.8856 - false_negatives: 2203.0000 - false_positives: 2372.0000 - val_loss: 0.3549 - val_binary_accuracy: 0.8520 - val_false_negatives: 526.0000 - val_false_positives: 214.0000
# Epoch 6/20
# 155/157 [============================>.] - ETA: 0s - loss: 0.2783 - binary_accuracy: 0.8913 - false_negatives: 2050.0000 - false_positives: 2265.0000
# Epoch 6: val_loss did not improve from 0.34529
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2785 - binary_accuracy: 0.8912 - false_negatives: 2067.0000 - false_positives: 2285.0000 - val_loss: 0.3888 - val_binary_accuracy: 0.8436 - val_false_negatives: 635.0000 - val_false_positives: 147.0000
# Epoch 6: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.3531179130077362, 'binary_accuracy': 0.852400004863739, 'false_negatives': 446.0, 'false_positives': 292.0}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Training via Active Learning
#
# The general process we follow when performing Active Learning is demonstrated below:
# ![dmNKusp.png](data:image/png;base64,...)
# The pipeline can be summarized in five parts:
#
# Sample and annotate a small, balanced training dataset
# Train the model on this small subset
# Evaluate the model on a balanced testing set
# If the model satisfies the business criteria, deploy it in a real time setting
# If it doesn't pass the criteria, sample a few more samples according to the ratio of false positives and negatives, add them to the training set and repeat from step 2 till the model passes the tests or till all available data is exhausted.
# For the code below, we will perform sampling using the following formula:
#
# Ratio Sampling
#
# Active Learning techniques use callbacks extensively for progress tracking. We will be using model checkpointing and early stopping for this example. The patience parameter for Early Stopping can help minimize overfitting and the time required. We have set it patience=4 for now but since the model is robust, we can increase the patience level if desired.
#
# Note: We are not loading the checkpoint after the first training iteration. In my experience working on Active Learning techniques, this helps the model probe the newly formed loss landscape. Even if the model fails to improve in the second iteration, we will still gain insight about the possible future false positive and negative rates. This will help us sample a better set in the next iteration where the model will have a greater chance to improve.

# %%
def train_active_learning_models(train_dataset,pool_negatives,pool_positives,
                                 val_dataset,test_dataset,num_iterations=3,sampling_size=5000,):
  # Creating lists for storing metrics
  losses, val_losses, accuracies, val_accuracies = [], [], [], []

  model = create_model()
  # We will monitor the false positives and false negatives predicted by our model
  # These will decide the subsequent sampling ratio for every Active Learning loop
  model.compile(
      loss="binary_crossentropy",
      optimizer="rmsprop",
      metrics=[
          keras.metrics.BinaryAccuracy(),
          keras.metrics.FalseNegatives(),
          keras.metrics.FalsePositives(),
      ],
  )

  # Defining checkpoints.
  # The checkpoint callback is reused throughout the training since it only saves the best overall model.
  checkpoint = keras.callbacks.ModelCheckpoint(
      "AL_Model.h5", save_best_only=True, verbose=1
  )
  # Here, patience is set to 4. This can be set higher if desired.
  early_stopping = keras.callbacks.EarlyStopping(patience=4, verbose=1)

  print(f"Starting to train with {len(train_dataset)} samples")
  # Initial fit with a small subset of the training set
  history = model.fit(
      train_dataset.cache().shuffle(20000).batch(256),
      epochs=20,
      validation_data=val_dataset,
      callbacks=[checkpoint, early_stopping],
  )

  # Appending history
  losses, val_losses, accuracies, val_accuracies = append_history(
      losses, val_losses, accuracies, val_accuracies, history
  )

  for iteration in range(num_iterations):
      # Getting predictions from previously trained model
      predictions = model.predict(test_dataset)

      # Generating labels from the output probabilities
      rounded = tf.where(tf.greater(predictions, 0.5), 1, 0)

      # Evaluating the number of zeros and ones incorrrectly classified
      _, _, false_negatives, false_positives = model.evaluate(test_dataset, verbose=0)

      print("-" * 100)
      print(
          f"Number of zeros incorrectly classified: {false_negatives}, Number of ones incorrectly classified: {false_positives}"
      )

      # This technique of Active Learning demonstrates ratio based sampling where
      # Number of ones/zeros to sample = Number of ones/zeros incorrectly classified / Total incorrectly classified
      if false_negatives != 0 and false_positives != 0:
          total = false_negatives + false_positives
          sample_ratio_ones, sample_ratio_zeros = (
              false_positives / total,
              false_negatives / total,
          )
      # In the case where all samples are correctly predicted, we can sample both classes equally
      else:
          sample_ratio_ones, sample_ratio_zeros = 0.5, 0.5

      print(
            f"Sample ratio for positives: {sample_ratio_ones}, Sample ratio for negatives:{sample_ratio_zeros}"
      )
      # Sample the required number of ones and zeros
      sampled_dataset = pool_negatives.take(
          int(sample_ratio_zeros * sampling_size)
      ).concatenate(pool_positives.take(int(sample_ratio_ones * sampling_size)))

      # Skip the sampled data points to avoid repetition of sample
      pool_negatives = pool_negatives.skip(int(sample_ratio_zeros * sampling_size))
      pool_positives = pool_positives.skip(int(sample_ratio_ones * sampling_size))

      # Concatenating the train_dataset with the sampled_dataset
      train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
          tf.data.AUTOTUNE
      )

      print(f"Starting training with {len(train_dataset)} samples")
      print("-" * 100)

      # We recompile the model to reset the optimizer states and retrain the model
      model.compile(
          loss="binary_crossentropy",
          optimizer="rmsprop",
          metrics=[
              keras.metrics.BinaryAccuracy(),
              keras.metrics.FalseNegatives(),
              keras.metrics.FalsePositives(),
          ],
      )
      history = model.fit(
          train_dataset.cache().shuffle(20000).batch(256),
          validation_data=val_dataset,
          epochs=20,
          callbacks=[
              checkpoint,
              keras.callbacks.EarlyStopping(patience=4, verbose=1),
          ],
      )

      # Appending the history
      losses, val_losses, accuracies, val_accuracies = append_history(
          losses, val_losses, accuracies, val_accuracies, history
      )

      # Loading the best model from this training loop
      model = keras.models.load_model("AL_Model.h5")

  # Plotting the overall history and evaluating the final model
  plot_history(losses, val_losses, accuracies, val_accuracies)
  print("-" * 100)
  print(
      "Test set evaluation: ",
      model.evaluate(test_dataset, verbose=0, return_dict=True),
  )
  print("-" * 100)

  return model



active_learning_model = train_active_learning_models(
    train_dataset, pool_negatives, pool_positives, val_dataset, test_dataset
)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 150, 128)          384000
#
#  bidirectional_3 (Bidirectio  (None, 150, 64)          41216
#  nal)
#
#  global_max_pooling1d_3 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dense_6 (Dense)             (None, 20)                1300
#
#  dropout_3 (Dropout)         (None, 20)                0
#
#  dense_7 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 426,537
# Trainable params: 426,537
# Non-trainable params: 0
# _________________________________________________________________
# Starting to train with 15000 samples
# Epoch 1/20
# 57/59 [===========================>..] - ETA: 0s - loss: 0.6503 - binary_accuracy: 0.6295 - false_negatives_4: 3212.0000 - false_positives_4: 2195.0000
# Epoch 1: val_loss improved from inf to 0.50421, saving model to AL_Model.h5
# 59/59 [==============================] - 8s 42ms/step - loss: 0.6470 - binary_accuracy: 0.6336 - false_negatives_4: 3242.0000 - false_positives_4: 2254.0000 - val_loss: 0.5042 - val_binary_accuracy: 0.7862 - val_false_negatives_4: 307.0000 - val_false_positives_4: 762.0000
# Epoch 2/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.4804 - binary_accuracy: 0.7975 - false_negatives_4: 1385.0000 - false_positives_4: 1621.0000
# Epoch 2: val_loss improved from 0.50421 to 0.49469, saving model to AL_Model.h5
# 59/59 [==============================] - 2s 27ms/step - loss: 0.4807 - binary_accuracy: 0.7980 - false_negatives_4: 1407.0000 - false_positives_4: 1623.0000 - val_loss: 0.4947 - val_binary_accuracy: 0.7604 - val_false_negatives_4: 87.0000 - val_false_positives_4: 1111.0000
# Epoch 3/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.4039 - binary_accuracy: 0.8415 - false_negatives_4: 1133.0000 - false_positives_4: 1221.0000
# Epoch 3: val_loss improved from 0.49469 to 0.37985, saving model to AL_Model.h5
# 59/59 [==============================] - 2s 26ms/step - loss: 0.4037 - binary_accuracy: 0.8411 - false_negatives_4: 1151.0000 - false_positives_4: 1232.0000 - val_loss: 0.3798 - val_binary_accuracy: 0.8374 - val_false_negatives_4: 227.0000 - val_false_positives_4: 586.0000
# Epoch 4/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.3627 - binary_accuracy: 0.8588 - false_negatives_4: 987.0000 - false_positives_4: 1109.0000
# Epoch 4: val_loss did not improve from 0.37985
# 59/59 [==============================] - 2s 26ms/step - loss: 0.3622 - binary_accuracy: 0.8586 - false_negatives_4: 992.0000 - false_positives_4: 1129.0000 - val_loss: 0.3860 - val_binary_accuracy: 0.8274 - val_false_negatives_4: 621.0000 - val_false_positives_4: 242.0000
# Epoch 5/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.3400 - binary_accuracy: 0.8710 - false_negatives_4: 870.0000 - false_positives_4: 1046.0000
# Epoch 5: val_loss did not improve from 0.37985
# 59/59 [==============================] - 2s 26ms/step - loss: 0.3407 - binary_accuracy: 0.8705 - false_negatives_4: 873.0000 - false_positives_4: 1070.0000 - val_loss: 0.3799 - val_binary_accuracy: 0.8292 - val_false_negatives_4: 607.0000 - val_false_positives_4: 247.0000
# Epoch 6/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.3121 - binary_accuracy: 0.8845 - false_negatives_4: 785.0000 - false_positives_4: 930.0000
# Epoch 6: val_loss improved from 0.37985 to 0.36943, saving model to AL_Model.h5
# 59/59 [==============================] - 2s 26ms/step - loss: 0.3131 - binary_accuracy: 0.8843 - false_negatives_4: 800.0000 - false_positives_4: 936.0000 - val_loss: 0.3694 - val_binary_accuracy: 0.8390 - val_false_negatives_4: 194.0000 - val_false_positives_4: 611.0000
# Epoch 7/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.2887 - binary_accuracy: 0.8944 - false_negatives_4: 740.0000 - false_positives_4: 828.0000
# Epoch 7: val_loss improved from 0.36943 to 0.35497, saving model to AL_Model.h5
# 59/59 [==============================] - 2s 27ms/step - loss: 0.2887 - binary_accuracy: 0.8944 - false_negatives_4: 744.0000 - false_positives_4: 840.0000 - val_loss: 0.3550 - val_binary_accuracy: 0.8466 - val_false_negatives_4: 343.0000 - val_false_positives_4: 424.0000
# Epoch 8/20
# 57/59 [===========================>..] - ETA: 0s - loss: 0.2737 - binary_accuracy: 0.9009 - false_negatives_4: 659.0000 - false_positives_4: 787.0000
# Epoch 8: val_loss did not improve from 0.35497
# 59/59 [==============================] - 2s 26ms/step - loss: 0.2722 - binary_accuracy: 0.9016 - false_negatives_4: 672.0000 - false_positives_4: 804.0000 - val_loss: 0.3840 - val_binary_accuracy: 0.8398 - val_false_negatives_4: 487.0000 - val_false_positives_4: 314.0000
# Epoch 9/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.2495 - binary_accuracy: 0.9116 - false_negatives_4: 613.0000 - false_positives_4: 699.0000
# Epoch 9: val_loss did not improve from 0.35497
# 59/59 [==============================] - 2s 26ms/step - loss: 0.2492 - binary_accuracy: 0.9117 - false_negatives_4: 618.0000 - false_positives_4: 706.0000 - val_loss: 0.4024 - val_binary_accuracy: 0.8430 - val_false_negatives_4: 342.0000 - val_false_positives_4: 443.0000
# Epoch 10/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.2324 - binary_accuracy: 0.9178 - false_negatives_4: 566.0000 - false_positives_4: 654.0000
# Epoch 10: val_loss did not improve from 0.35497
# 59/59 [==============================] - 2s 26ms/step - loss: 0.2324 - binary_accuracy: 0.9179 - false_negatives_4: 573.0000 - false_positives_4: 658.0000 - val_loss: 0.3968 - val_binary_accuracy: 0.8404 - val_false_negatives_4: 403.0000 - val_false_positives_4: 395.0000
# Epoch 11/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.2230 - binary_accuracy: 0.9253 - false_negatives_4: 505.0000 - false_positives_4: 604.0000
# Epoch 11: val_loss did not improve from 0.35497
# 59/59 [==============================] - 2s 26ms/step - loss: 0.2224 - binary_accuracy: 0.9256 - false_negatives_4: 510.0000 - false_positives_4: 606.0000 - val_loss: 0.4102 - val_binary_accuracy: 0.8352 - val_false_negatives_4: 429.0000 - val_false_positives_4: 395.0000
# Epoch 11: early stopping
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 460.0, Number of ones incorrectly classified: 382.0
# Sample ratio for positives: 0.45368171021377673, Sample ratio for negatives:0.5463182897862233
# Starting training with 19999 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 77/79 [============================>.] - ETA: 0s - loss: 0.2715 - binary_accuracy: 0.9023 - false_negatives_5: 862.0000 - false_positives_5: 1063.0000
# Epoch 1: val_loss did not improve from 0.35497
# 79/79 [==============================] - 8s 36ms/step - loss: 0.2717 - binary_accuracy: 0.9020 - false_negatives_5: 869.0000 - false_positives_5: 1090.0000 - val_loss: 0.3952 - val_binary_accuracy: 0.8370 - val_false_negatives_5: 293.0000 - val_false_positives_5: 522.0000
# Epoch 2/20
# 77/79 [============================>.] - ETA: 0s - loss: 0.2389 - binary_accuracy: 0.9180 - false_negatives_5: 735.0000 - false_positives_5: 882.0000
# Epoch 2: val_loss did not improve from 0.35497
# 79/79 [==============================] - 2s 25ms/step - loss: 0.2407 - binary_accuracy: 0.9168 - false_negatives_5: 736.0000 - false_positives_5: 927.0000 - val_loss: 0.4059 - val_binary_accuracy: 0.8344 - val_false_negatives_5: 547.0000 - val_false_positives_5: 281.0000
# Epoch 3/20
# 78/79 [============================>.] - ETA: 0s - loss: 0.2239 - binary_accuracy: 0.9231 - false_negatives_5: 728.0000 - false_positives_5: 808.0000
# Epoch 3: val_loss did not improve from 0.35497
# 79/79 [==============================] - 2s 30ms/step - loss: 0.2238 - binary_accuracy: 0.9231 - false_negatives_5: 728.0000 - false_positives_5: 809.0000 - val_loss: 0.4371 - val_binary_accuracy: 0.8342 - val_false_negatives_5: 516.0000 - val_false_positives_5: 313.0000
# Epoch 4/20
# 79/79 [==============================] - ETA: 0s - loss: 0.2083 - binary_accuracy: 0.9294 - false_negatives_5: 663.0000 - false_positives_5: 749.0000
# Epoch 4: val_loss did not improve from 0.35497
# 79/79 [==============================] - 2s 24ms/step - loss: 0.2083 - binary_accuracy: 0.9294 - false_negatives_5: 663.0000 - false_positives_5: 749.0000 - val_loss: 0.4510 - val_binary_accuracy: 0.8254 - val_false_negatives_5: 179.0000 - val_false_positives_5: 694.0000
# Epoch 5/20
# 78/79 [============================>.] - ETA: 0s - loss: 0.1916 - binary_accuracy: 0.9381 - false_negatives_5: 563.0000 - false_positives_5: 673.0000
# Epoch 5: val_loss did not improve from 0.35497
# 79/79 [==============================] - 2s 24ms/step - loss: 0.1919 - binary_accuracy: 0.9379 - false_negatives_5: 569.0000 - false_positives_5: 673.0000 - val_loss: 0.5287 - val_binary_accuracy: 0.8040 - val_false_negatives_5: 136.0000 - val_false_positives_5: 844.0000
# Epoch 5: early stopping
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 397.0, Number of ones incorrectly classified: 392.0
# Sample ratio for positives: 0.4968314321926489, Sample ratio for negatives:0.5031685678073511
# Starting training with 24998 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 96/98 [============================>.] - ETA: 0s - loss: 0.3275 - binary_accuracy: 0.8740 - false_negatives_6: 1464.0000 - false_positives_6: 1633.0000
# Epoch 1: val_loss improved from 0.35497 to 0.34596, saving model to AL_Model.h5
# 98/98 [==============================] - 10s 42ms/step - loss: 0.3277 - binary_accuracy: 0.8740 - false_negatives_6: 1487.0000 - false_positives_6: 1663.0000 - val_loss: 0.3460 - val_binary_accuracy: 0.8532 - val_false_negatives_6: 239.0000 - val_false_positives_6: 495.0000
# Epoch 2/20
# 96/98 [============================>.] - ETA: 0s - loss: 0.2931 - binary_accuracy: 0.8913 - false_negatives_6: 1233.0000 - false_positives_6: 1439.0000
# Epoch 2: val_loss improved from 0.34596 to 0.34208, saving model to AL_Model.h5
# 98/98 [==============================] - 2s 24ms/step - loss: 0.2936 - binary_accuracy: 0.8909 - false_negatives_6: 1262.0000 - false_positives_6: 1465.0000 - val_loss: 0.3421 - val_binary_accuracy: 0.8496 - val_false_negatives_6: 404.0000 - val_false_positives_6: 348.0000
# Epoch 3/20
# 97/98 [============================>.] - ETA: 0s - loss: 0.2760 - binary_accuracy: 0.8974 - false_negatives_6: 1198.0000 - false_positives_6: 1350.0000
# Epoch 3: val_loss did not improve from 0.34208
# 98/98 [==============================] - 2s 23ms/step - loss: 0.2762 - binary_accuracy: 0.8973 - false_negatives_6: 1204.0000 - false_positives_6: 1364.0000 - val_loss: 0.3510 - val_binary_accuracy: 0.8414 - val_false_negatives_6: 475.0000 - val_false_positives_6: 318.0000
# Epoch 4/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2601 - binary_accuracy: 0.9058 - false_negatives_6: 1112.0000 - false_positives_6: 1244.0000
# Epoch 4: val_loss did not improve from 0.34208
# 98/98 [==============================] - 2s 24ms/step - loss: 0.2601 - binary_accuracy: 0.9058 - false_negatives_6: 1112.0000 - false_positives_6: 1244.0000 - val_loss: 0.3643 - val_binary_accuracy: 0.8444 - val_false_negatives_6: 447.0000 - val_false_positives_6: 331.0000
# Epoch 5/20
# 96/98 [============================>.] - ETA: 0s - loss: 0.2460 - binary_accuracy: 0.9145 - false_negatives_6: 979.0000 - false_positives_6: 1122.0000
# Epoch 5: val_loss did not improve from 0.34208
# 98/98 [==============================] - 2s 23ms/step - loss: 0.2465 - binary_accuracy: 0.9143 - false_negatives_6: 1002.0000 - false_positives_6: 1141.0000 - val_loss: 0.3626 - val_binary_accuracy: 0.8456 - val_false_negatives_6: 316.0000 - val_false_positives_6: 456.0000
# Epoch 6/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2299 - binary_accuracy: 0.9200 - false_negatives_6: 925.0000 - false_positives_6: 1074.0000
# Epoch 6: val_loss did not improve from 0.34208
# 98/98 [==============================] - 2s 23ms/step - loss: 0.2299 - binary_accuracy: 0.9200 - false_negatives_6: 925.0000 - false_positives_6: 1074.0000 - val_loss: 0.3894 - val_binary_accuracy: 0.8468 - val_false_negatives_6: 301.0000 - val_false_positives_6: 465.0000
# Epoch 6: early stopping
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 419.0, Number of ones incorrectly classified: 326.0
# Sample ratio for positives: 0.4375838926174497, Sample ratio for negatives:0.5624161073825503
# Starting training with 29997 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 118/118 [==============================] - ETA: 0s - loss: 0.3008 - binary_accuracy: 0.8860 - false_negatives_7: 1616.0000 - false_positives_7: 1803.0000
# Epoch 1: val_loss did not improve from 0.34208
# 118/118 [==============================] - 13s 57ms/step - loss: 0.3008 - binary_accuracy: 0.8860 - false_negatives_7: 1616.0000 - false_positives_7: 1803.0000 - val_loss: 0.3437 - val_binary_accuracy: 0.8496 - val_false_negatives_7: 392.0000 - val_false_positives_7: 360.0000
# Epoch 2/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2790 - binary_accuracy: 0.8969 - false_negatives_7: 1432.0000 - false_positives_7: 1662.0000
# Epoch 2: val_loss did not improve from 0.34208
# 118/118 [==============================] - 3s 23ms/step - loss: 0.2790 - binary_accuracy: 0.8969 - false_negatives_7: 1432.0000 - false_positives_7: 1662.0000 - val_loss: 0.3597 - val_binary_accuracy: 0.8466 - val_false_negatives_7: 492.0000 - val_false_positives_7: 275.0000
# Epoch 3/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2601 - binary_accuracy: 0.9049 - false_negatives_7: 1324.0000 - false_positives_7: 1530.0000
# Epoch 3: val_loss did not improve from 0.34208
# 118/118 [==============================] - 3s 23ms/step - loss: 0.2601 - binary_accuracy: 0.9049 - false_negatives_7: 1324.0000 - false_positives_7: 1530.0000 - val_loss: 0.3744 - val_binary_accuracy: 0.8448 - val_false_negatives_7: 458.0000 - val_false_positives_7: 318.0000
# Epoch 4/20
# 117/118 [============================>.] - ETA: 0s - loss: 0.2425 - binary_accuracy: 0.9128 - false_negatives_7: 1204.0000 - false_positives_7: 1407.0000
# Epoch 4: val_loss did not improve from 0.34208
# 118/118 [==============================] - 3s 24ms/step - loss: 0.2425 - binary_accuracy: 0.9128 - false_negatives_7: 1205.0000 - false_positives_7: 1410.0000 - val_loss: 0.3769 - val_binary_accuracy: 0.8460 - val_false_negatives_7: 412.0000 - val_false_positives_7: 358.0000
# Epoch 5/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2306 - binary_accuracy: 0.9188 - false_negatives_7: 1158.0000 - false_positives_7: 1279.0000
# Epoch 5: val_loss did not improve from 0.34208
# 118/118 [==============================] - 3s 23ms/step - loss: 0.2306 - binary_accuracy: 0.9188 - false_negatives_7: 1158.0000 - false_positives_7: 1279.0000 - val_loss: 0.3646 - val_binary_accuracy: 0.8472 - val_false_negatives_7: 369.0000 - val_false_positives_7: 395.0000
# Epoch 5: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.3537566065788269, 'binary_accuracy': 0.8510000109672546, 'false_negatives_6': 419.0, 'false_positives_6': 326.0}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Conclusion
# Active Learning is a growing area of research. This example demonstrates the cost-efficiency benefits of using Active Learning, as it eliminates the need to annotate large amounts of data, saving resources.
#
# The following are some noteworthy observations from this example:
#
# We only require 30,000 samples to reach the same (if not better) scores as the model trained on the full datatset. This means that in a real life setting, we save the effort required for annotating 10,000 images!
# The number of false negatives and false positives are well balanced at the end of the training as compared to the skewed ratio obtained from the full training. This makes the model slightly more useful in real life scenarios where both the labels hold equal importance.
# For further reading about the types of sampling ratios, training techniques or available open source libraries/implementations, you can refer to the resources below:
#
# Active Learning Literature Survey (Burr Settles, 2010).
# modAL: A Modular Active Learning framework.
# Google's unofficial Active Learning playground.
